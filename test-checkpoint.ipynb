# %%
# !pip install nltk
# !pip install spacy
# !pip install spacy_langdetect
# Out:
# ...
#   Created wheel for langdetect: filename=langdetect-1.0.7-py3-none-any.whl size=993464 sha256=195bbaef7858768c7d22cfca12c79775c6da524ef493c87b46b8e0692e43862c
#   Stored in directory: c:\users\alexj\appdata\local\pip\cache\wheels\c1\6d\ab\bf9ecd1ab14dd236da586dfd0d4b008e2e803e571cf2229c26
# Successfully built langdetect
# ...

# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# Finished.
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\alexj\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\brown.zip.
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\alexj\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\alexj\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\wordnet.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\alexj\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package conll2000 to
# [nltk_data]     C:\Users\alexj\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\conll2000.zip.
# [nltk_data] Downloading package movie_reviews to
# ...

# %%
# !pip install spacytextblob
# Out:
# ...
#   Attempting uninstall: textblob
#     Found existing installation: textblob 0.17.1
#     Uninstalling textblob-0.17.1:
#       Successfully uninstalled textblob-0.17.1
# ...

# %%
import pandas as pd
import numpy as np

import nltk
import spacy

#from tqdm.auto import tqdm 
#tqdm.pandas()

# %%
from spacy.language import Language
from spacy_langdetect import LanguageDetector
from spacytextblob.spacytextblob import SpacyTextBlob

@Language.factory("language_detector")
def create_language_detector(nlp, name):
    return LanguageDetector(language_detection_function=None)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-92-19fd60a6bc12> in <module>
#       4
#       5 @Language.factory("language_detector")
# ----> 6 def create_language_detector(nlp, name):
#       7     return LanguageDetector(language_detection_function=None)
#       8
#
# ~\anaconda3\lib\site-packages\spacy\language.py in add_factory(factory_func)
#     481                         name=name, func=existing_func, new_func=factory_func
#     482                     )
# --> 483                     raise ValueError(err)
#     484
#     485             arg_names = util.get_arg_names(factory_func)
#
# ValueError: [E004] Can't set up pipeline component: a factory for 'language_detector' already exists. Existing factory: <function create_language_detector at 0x000002818875E9D0>. New factory: <function create_language_detector at 0x0000028188537EE0>

# %%
nlp = spacy.load("en_core_web_sm")

nlp.add_pipe('language_detector')
nlp.add_pipe('spacytextblob')

# %%
df = pd.read_csv(r"https://www.ecb.europa.eu/press/key/shared/data/all_ECB_speeches.csv?848ea64ce6d77827b5e8e18790878b64",index_col = ["date"] , sep = "|",encoding='utf-8')

# %%
df = df.dropna()[df['contents']!=" "]

# %%
df["nlp"] = df["contents"].apply(lambda x: nlp(x))

# %%
df['nlp'].apply(lambda x: x._.language['language']=="en")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-145-308c75dd2b07> in <module>
# ----> 1 df['nlp'].apply(lambda x: x._.language['language']==x.lang_)
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#    1096                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1097                 # "Callable[[Any], Any]"
# ...

# %%
# Out:
# 'en'

# %%
df["nlp"].sample(1)[0]._.assessments
# Out:
# [(['economic'], 0.2, 0.2, None),
#  (['public'], 0.0, 0.06666666666666667, None),
#  (['economic'], 0.2, 0.2, None),
#  (['european'], 0.0, 0.0, None),
#  (['economic'], 0.2, 0.2, None),
#  (['glad'], 0.5, 1.0, None),
#  (['new'], 0.13636363636363635, 0.45454545454545453, None),
#  (['european'], 0.0, 0.0, None),
#  (['essential'], 0.0, 0.3, None),
#  (['strongly'], 0.4333333333333333, 0.7333333333333333, None),
#  (['only'], 0.0, 1.0, None),
#  (['first'], 0.25, 0.3333333333333333, None),
#  (['first'], 0.25, 0.3333333333333333, None),
#  (['european'], 0.0, 0.0, None),
#  (['live'], 0.13636363636363635, 0.5, None),
#  (['next'], 0.0, 0.0, None),
#  (['more'], 0.5, 0.5, None),
#  (['more'], 0.5, 0.5, None),
#  (['total'], 0.0, 0.75, None),
#  (['new'], 0.13636363636363635, 0.45454545454545453, None),
#  (['single'], -0.07142857142857142, 0.21428571428571427, None),
#  (['good'], 0.7, 0.6000000000000001, None),
#  (['further'], 0.0, 0.5, None),
#  (['related'], 0.0, 0.4, None),
# ...

# %%
doc = df["nlp"].sample(1)[0]
for chunk in doc.noun_chunks:
    print(chunk.text)
# Out:
# Monetary policy-making
# uncertainty
# Conference
# the European Central Bank
# ECB
# the Center
# Financial Studies
# Frankfurt
# Dr. Willem F. Duisenberg
# President
# the European Central Bank
# 3 December
# Frankfurt
# Main Ladies
# gentlemen
# It
# a great pleasure
# you
# Frankfurt
# the occasion
# the conference
# "Monetary policy-making
# uncertainty
# the European Central Bank
# ECB
# the Center
# Financial Studies
# the University
# Frankfurt
# you
# I
# the opportunity
# many "firsts
# recent times
# It
# all
# 9 June
# the Governing Council
# the ECB
# the first time
# 4 January
# the first transactions
# euro
# the money
# foreign exchange markets
# the first payments
# euro
# the new TARGET system
# the first decision
# official interest rates
# the Governing Council
# 8 April
# I
# the light
# the unique historical journey
# which
# we
# a consequence
# the establishment
# a single currency
# 11 sovereign countries
# the smooth and successful start
# Stage
# a tribute
# ...
